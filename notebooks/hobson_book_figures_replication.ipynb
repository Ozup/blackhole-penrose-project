# %%
# Para trabajar con carpetas
import sys
import os

sys.path.append(os.path.abspath(".."))
#############################

import numpy as np
import matplotlib.pyplot as plt
from src.functions import functions_blackholes as fbh

import importlib
importlib.reload(fbh)

C = 0
mu = 4
c = 1

# %%
r = np.linspace(0.000,100,500)

plt.figure(figsize=(10,10))
color = "darkolivegreen"

linew = 1.5

fbh.plotlightcone(r, -24, mu = mu, col = color, linew = linew)
fbh.plotlightcone(r, -19, mu = mu, col = color, linew = linew )
fbh.plotlightcone(r, -14, mu = mu, col = color, linew = linew )
fbh.plotlightcone(r, -9, mu = mu, col = color, linew = linew )
fbh.plotlightcone(r, -4, mu = mu, col = color, linew = linew )
fbh.plotlightcone(r, 1, mu = mu, col = color, linew = linew )
fbh.plotlightcone(r, 5, mu = mu, col = color, linew = linew)
fbh.plotlightcone(r, 10, mu = mu, col = color, linew = linew )
fbh.plotlightcone(r, 15, mu = mu, col = color, linew = linew )
fbh.plotlightcone(r, 20, mu = mu, col = color, linew = linew )
fbh.plotlightcone(r, 25, mu = mu, col = color, linew = linew )
fbh.plotlightcone(r, 30, mu = mu, col = color, linew = linew )
fbh.plotlightcone(r, 35, mu = mu, col = color, linew = linew )

# plt.plot(r_values, t_values-100, color="blue")
# plt.plot(r_values, t_values_neg-90, color = "blue")

plt.xlim(0, 20)
plt.ylim(0, 20)

plt.xlabel(r"$r$",fontsize=18)
plt.ylabel(r"$ct$", fontsize=18)

plt.axvline(x=2*mu, color="black", linewidth= 0.8)

# plt.plot(0,0,color="lightcoral", linestyle="-",label="Saliente")
# plt.plot(0,0,color="lightcoral", linestyle="--",label="Entrante")

#plt.title(r"Líneas de mundo para un fotón con $\theta$ y $\phi$ constantes ($\mu = 1$; $c=1$)", fontsize= 10)

#plt.text(2*mu + 0.1,2.5, r"$r = 2\mu$", rotation = 90)

plt.xticks([])
plt.yticks([])

plt.xticks([2*mu], [r"$r = 2\mu$"], fontsize=18)
#plt.xticks([0], [r"$r = 0$"], fontsize=18)
#plt.axis('off')

plt.text(3,10, "II", fontsize=20 , color="black", alpha= 0.3)
plt.text(14,10, "I", fontsize=20 , color="black", alpha= 0.3)
plt.text(0, -0.8, r"$r=0$",ha="center",  fontsize=18)

plt.savefig("../figures/figure_11_1.png", dpi=300, bbox_inches="tight")
#plt.legend()
plt.show()

# %% [markdown]
# Aquí haré como son los cono de luz en Minkowski

# %%
plt.figure(figsize=(10,10))
color = "darkolivegreen"

def line(x, C, signo = 1):
    return signo*x + C

def plotline(x, C, col = "darkolivegreen", linew=1):
    plt.plot(x, line(x, C, signo=1), color = col, linewidth= linew)
    plt.plot(x, line(x, C, signo=-1), color = col, linewidth= linew, linestyle="--")

# %%
r = np.linspace(-100,100,100)
plt.figure(figsize=(10,10))
plotline(r, 0, linew= linew)
plotline(r, 5, linew= linew)
plotline(r, 10, linew= linew)
plotline(r, 15, linew= linew)
plotline(r, 20, linew= linew)
plotline(r, 25, linew= linew)
plotline(r, 30, linew= linew)
plotline(r, 35, linew= linew)


plotline(r, 0, linew= linew)
plotline(r, -5, linew= linew)
plotline(r, -10, linew= linew)
plotline(r, -15, linew= linew)
plotline(r, -20, linew= linew)
plotline(r, -25, linew= linew)
plotline(r, -30, linew= linew)
plotline(r, -35, linew= linew)


plt.xticks([])
plt.yticks([])

plt.xlabel(r"$r$",fontsize=18)
plt.ylabel(r"$ct$", fontsize=18)

plt.xticks([2*mu], [r"$r = 2\mu$"], fontsize=18)

plt.xlim(0, 20)
plt.ylim(0, 20)

plt.text(12,10, "I", fontsize=20 , color="black", alpha= 0.3)
plt.savefig("../figures/figure_11_1_extra.png", dpi=300, bbox_inches="tight")

# %%
mu = 1
r = np.linspace(0,20,1000)
plt.figure(figsize=(10,10))
# plotlightcone2(r, 1)
# plotlightcone2(r, 3)
fbh.plotlightcone2(r, 6, col = color, mu = mu, linew=linew)
fbh.plotlightcone2(r, 12, col = color, mu = mu, linew=linew)
fbh.plotlightcone2(r, 18, col = color, mu = mu, linew=linew)
fbh.plotlightcone2(r, 24, col = color, mu = mu, linew=linew)
fbh.plotlightcone2(r, 30, col = color, mu = mu, linew=linew)
fbh.plotlightcone2(r, 36, col = color, mu = mu, linew=linew)

fbh.plotlightcone2(r,-24, col = color, mu = mu, linew=linew)

fbh.plotlightcone2(r, -1, col = color, mu = mu, linew=linew)
fbh.plotlightcone2(r, -6, col = color, mu = mu, linew=linew)
fbh.plotlightcone2(r, -12, col = color, mu = mu, linew=linew)
fbh.plotlightcone2(r, -18, col = color, mu = mu, linew=linew)

plt.xlim(0, 12)
plt.ylim(0,20)

r0=8
#plt.plot(r, fbh.time_11_4(r0, r, mu)*mu + 2*mu*np.log(abs(r/(2*mu)-1)), color = "gray", linewidth=0.9)

plt.xlabel(r"$r$",fontsize=18)
plt.ylabel(r"$ct'$", fontsize=18)

plt.axvline(x=2*mu, color="black")

plt.plot(0,0,color="darkcyan", linestyle="-",label="Saliente (Outgoing)")
plt.plot(0,0,color="skyblue", linestyle="--",label="Entrante (Incoming)")

#plt.title(r"Líneas de mundo para un fotón con $\theta$ y $\phi$ constantes ($\mu = 1$; $c=1$)")
#plt.title("Estrucura del cono de luz en coordenadas de Eddintong-Finkelstein", fontsize=10)
#plt.legend(fontsize=10)

#plt.text(2.1,5, r"$r=2\mu$", rotation = 90, fontsize=12)
plt.text(1,10, "II", fontsize=20 , color="black", alpha= 0.3)
plt.text(11,10, "I", fontsize=20 , color="black", alpha= 0.3)
plt.xticks([])
plt.yticks([])
plt.text(0, -0.8, r"$r=0$",ha="center",  fontsize=18)
plt.xticks([2*mu], [r"$r = 2\mu$"], fontsize=18)
plt.xlim(0, 20)
plt.ylim(0, 20)
plt.savefig("../figures/figure_11_3.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
mu = 1
r = np.linspace(0,20,1000)
plt.figure(figsize=(10,10))
# plotlightcone2(r, 1)
# plotlightcone2(r, 3)
fbh.plotlightcone3(r, 6, col = color, mu = mu, linew=linew)
fbh.plotlightcone3(r, 12, col = color, mu = mu, linew=linew)
fbh.plotlightcone3(r, 18, col = color, mu = mu, linew=linew)
fbh.plotlightcone3(r, 24, col = color, mu = mu, linew=linew)
fbh.plotlightcone3(r, 30, col = color, mu = mu, linew=linew)
fbh.plotlightcone3(r, 36, col = color, mu = mu, linew=linew)



fbh.plotlightcone3(r, -1, col = color, mu = mu, linew=linew)
fbh.plotlightcone3(r, -6, col = color, mu = mu, linew=linew)
fbh.plotlightcone3(r, -12, col = color, mu = mu, linew=linew)
fbh.plotlightcone3(r, -18, col = color, mu = mu, linew=linew)

fbh.plotlightcone3(r,42, col = color, mu = mu, linew=linew)

plt.xlim(0, 12)
plt.ylim(0,20)

r0=8
#plt.plot(r, fbh.time_11_4(r0, r, mu)*mu + 2*mu*np.log(abs(r/(2*mu)-1)), color = "gray", linewidth=0.9)

plt.xlabel(r"$r$",fontsize=18)
plt.ylabel(r"$ct'$", fontsize=18)

plt.axvline(x=2*mu, color="black")

plt.plot(0,0,color="darkcyan", linestyle="-",label="Saliente (Outgoing)")
plt.plot(0,0,color="skyblue", linestyle="--",label="Entrante (Incoming)")

#plt.title(r"Líneas de mundo para un fotón con $\theta$ y $\phi$ constantes ($\mu = 1$; $c=1$)")
#plt.title("Estrucura del cono de luz en coordenadas de Eddintong-Finkelstein", fontsize=10)
#plt.legend(fontsize=10)

#plt.text(2.1,5, r"$r=2\mu$", rotation = 90, fontsize=12)
plt.text(1,10, "II", fontsize=20 , color="black", alpha= 0.3)
plt.text(10,10, "I", fontsize=20 , color="black", alpha= 0.3)
plt.xticks([])
plt.yticks([])
plt.text(0, -0.8, r"$r=0$",ha="center",  fontsize=18)
plt.xticks([2*mu], [r"$r = 2\mu$"], fontsize=18)
plt.xlim(0, 20)
plt.ylim(0, 20)
plt.savefig("../figures/figure_11_3_extra.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
u = np.linspace(-100,100,10000)
r = np.linspace(0,10,10000)
plt.figure(figsize=(10,10))

import warnings

# Suprimir las advertencias específicas
warnings.filterwarnings("ignore", category=RuntimeWarning)

plt.axhline(0, color = "black", linewidth=0.8)
#plt.axvline(0, color = "black", linewidth=0.8)
plt.plot([0,0],[-1,1], color = "black", linewidth=0.8)


# Hiperbola de r = 0
plt.plot(u, fbh.v_coord(u)[0], color = "black", linewidth=0.5)
plt.plot(u, fbh.v_coord(u)[1], color = "black", linewidth=0.5)

# Línea recta
C = 0
plt.plot(u, fbh.v_coord_1(u, C)[0], color = "black", linewidth=0.5)
plt.plot(u, fbh.v_coord_1(u, C)[1], color = "black", linewidth=0.5)

# HIPERBOLAS de r constante
a = 3
fbh.hip_rconst(r, a, C)

a = 2.5
fbh.hip_rconst(r, a, C)

a = 1.8
fbh.hip_rconst(r, a, C)

a = 1
fbh.hip_rconst(r, a, C)

# RECTAS de t constante
t = 1
fbh.rec_tconst(r, t, C)

t = 3
fbh.rec_tconst(r, t, C)

r0 = 3
fbh.plot_masspart(r0)

fbh.plot_photon(r0)

# plt.plot(u_mayor(r0, r), v_mayor(r0, r))

f= 2
plt.xlim(-f,f)
plt.ylim(-f,f)

#plt.title("Geometría de Schwarzschild en coordenadas de Kruskal", fontsize=10)
plt.plot(0,0, linestyle="--", color="teal" ,label = "Líneas de r constante", linewidth=0.7)
plt.plot(0,0, linestyle="--", color="olive" ,label = "Líneas de t constante", linewidth=0.7)


#plt.text(1.8,0.9, r"$r=3\mu$", rotation=65, fontsize=9, color="teal")

plt.plot(0,0, color="goldenrod", label="Trayectoria de un fotón entrante", linewidth=0.7)

plt.plot(0,0, color="salmon", label="Trayectoria de una partícula con masa", linewidth=0.7)

# Zonas

plt.text(1.2,0.1,"I",fontsize=20, color = "black", alpha=0.2)

plt.text(-1.2,0.1,"I'",fontsize=20, color = "black", alpha=0.2)

plt.text(0.2,0.8,"II",fontsize=20, color = "black", alpha=0.2)

plt.text(0.2,-0.8,"II'",fontsize=20, color = "black", alpha=0.2)

#Textos
plt.text(1.4,1.3, r"$r=2\mu  \ \ t \rightarrow \infty$", rotation=45, fontsize=12)

plt.text(-1.8,1.3, r"$r=2\mu  \ \ t \rightarrow \infty$", rotation=-45, fontsize=12)

plt.text(-1.8,-1.7, r"$r=2\mu  \ \ t \rightarrow \infty$", rotation=45, fontsize=12)

plt.text(1.4,-1.7, r"$r=2\mu  \ \ t \rightarrow \infty$", rotation=-45, fontsize=12)


plt.xticks([])
plt.yticks([])


plt.xlabel(r'$u$',fontsize=18)
plt.ylabel(r"$v$", fontsize=18)
plt.text(-0.1,1.06, r"$r=0$", rotation=-0, fontsize=12)

plt.legend(fontsize=12)
plt.savefig("../figures/figure_11_6.png", dpi=300, bbox_inches="tight")

# %%
def r_pm(signo=1, mu=1, q=0.9):
  #if abs(mu) < abs(q):
  return mu + signo*(mu**2 - q**2)**(1/2)

def ct_RN(r, C, mu, q, signo=1):
  r_p = r_pm(signo=1, mu=mu, q=q)
  r_m = r_pm(signo=-1, mu=mu, q=q)
  ct = signo*(r - ((r_m**2)/(r_p-r_m))*np.log(abs(r/r_m -1)) + ((r_p**2)/(r_p-r_m))*np.log(abs(r/r_p -1)) ) + C
  return ct

def plotlightcone_RN(r, C, mu, q, col="darkolivegreen"):
  """
  Grafica las lineas de mundo de fotones entrantes y saleintes en coordenadas de Schwarzschild.
  r: Distancias radiales que se desea graficar. (array)
  C: Constante arbitraría que desplaza hacia arriba o hacia abajo las curvas. (float)
  col: Color de la gráfica (Opcinal, está por defecto en lightcoral). (str)
  mu: Es la abreviación de GM (Opcional, trabajamos normalmente con mu=1). (float)
  """
  plt.plot(r, ct_RN(r, C, mu, q, signo = 1), color = col, linewidth= 1)
  plt.plot(r, ct_RN(r, C, mu, q, signo = -1), color = col, linestyle="--", linewidth= 1)
  return

# %%
def g00_RN(r, mu, q):
    return 1 - 2*mu/r + (q**2)/(r**2)

def g00_SW(r, mu):
    return 1 -2*mu/r

# %%
r = np.linspace(0.000,100,10000)

plt.figure(figsize=(10,10))

mu = 1
q = 0.9

plotlightcone_RN(r, -24, mu=mu, q=q)
plotlightcone_RN(r, -19, mu=mu, q=q)
plotlightcone_RN(r, -14, mu=mu, q=q)
plotlightcone_RN(r, -9, mu=mu, q=q)
plotlightcone_RN(r, -4, mu=mu, q=q)
plotlightcone_RN(r, 1, mu=mu, q=q)
plotlightcone_RN(r, 5, mu=mu, q=q)
plotlightcone_RN(r, 10, mu=mu, q=q)
plotlightcone_RN(r, 15, mu=mu, q=q)
plotlightcone_RN(r, 20, mu=mu, q=q)
plotlightcone_RN(r, 25, mu=mu, q=q)
plotlightcone_RN(r, 30, mu=mu, q=q)
plotlightcone_RN(r, 35, mu=mu, q=q)

# Integracion
# plt.plot(r_values, t_values-100, color="blue")
# plt.plot(r_values, t_values_neg-90, color = "blue")

plt.xlim(0, 2)
plt.ylim(0, 20)

plt.axvline(r_pm(signo=1, mu=mu, q=q),color = "black", linewidth=1)
plt.axvline(r_pm(signo=-1, mu=mu, q=q), color = "black" , linewidth=1)

plt.xlabel(r"$r$",fontsize=18)
plt.ylabel(r"$ct'$", fontsize=18)
#plt.title("Coordenadas Reissner-Nordström", fontsize=10)

plt.xticks([])
plt.yticks([])
plt.text(0, -0.8, r"$r=0$",ha="center",  fontsize=18)
plt.text(0, -0.8, r"$r=0$",ha="center",  fontsize=18)

plt.text(1.45, -0.8, r"$r_+$",ha="center",  fontsize=18)
plt.xticks([0.56], [r"$r_-$"], fontsize=18)

plt.text(1.7,11, "I", fontsize=20 , color="black", alpha= 0.3)

plt.text(1,11, "II", fontsize=20 , color="black", alpha= 0.3)

plt.text(0.25,11, "III", fontsize=20 , color="black", alpha= 0.3)

plt.savefig("../figures/figure_extra_rnbh.png", dpi=300, bbox_inches="tight")
